# %% [markdown]
# # Q1 — Vision Transformer (ViT) on CIFAR-10
#
# Implementation of ViT in PyTorch.

# %%
# ==============================
# 1. Setup & Imports
# ==============================
import os, random, math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import LambdaLR

# Reproducibility
seed = 0
random.seed(seed); np.random.seed(seed)
torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.benchmark = True
torch.backends.cudnn.deterministic = False

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# Device: Tesla T4

# %%
# ==============================
# 2. Data & Augmentations
# ==============================
mean = (0.4914, 0.4822, 0.4465)
std  = (0.2470, 0.2435, 0.2616)

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandAugment(num_ops=2, magnitude=9),
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

train_ds = datasets.CIFAR10('./data', train=True, download=True, transform=train_transform)
val_ds   = datasets.CIFAR10('./data', train=False, download=True, transform=val_transform)

batch_size = 128
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader   = DataLoader(val_ds, batch_size=256, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# 100%|██████████| 170M/170M [00:06<00:00, 27.4MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# ==============================
# 3. MixUp helper
# ==============================
def mixup_data(x, y, alpha=0.8, device='cuda'):
    if alpha <= 0:
        return x, y, 1.0, None
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
# ==============================
# 4. Vision Transformer (ViT)
# ==============================
class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob
    def forward(self, x):
        if self.drop_prob == 0. or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor

class PatchEmbed(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_chans=3, embed_dim=256):
        super().__init__()
        self.n_patches = (img_size // patch_size) ** 2
        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)
    def forward(self, x):
        x = self.proj(x)             # B, embed_dim, H/ps, W/ps
        x = x.flatten(2).transpose(1,2)  # B, N, C
        return x

class MLP(nn.Module):
    def __init__(self, in_features, hidden_features=None, drop=0.):
        super().__init__()
        hidden_features = hidden_features or in_features
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = nn.GELU()
        self.fc2 = nn.Linear(hidden_features, in_features)
        self.drop = nn.Dropout(drop)
    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x

class Attention(nn.Module):
    def __init__(self, dim, num_heads=8, qkv_bias=True, attn_drop=0., proj_drop=0.):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        self.qkv = nn.Linear(dim, dim*3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)
    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, C // self.num_heads).permute(2,0,3,1,4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2,-1)) * self.scale
        attn = attn.softmax(dim=-1)
        attn = self.attn_drop(attn)
        x = (attn @ v).transpose(1,2).reshape(B, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x

class Block(nn.Module):
    def __init__(self, dim, num_heads, mlp_ratio=4., drop=0., attn_drop=0., drop_path=0.):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = Attention(dim, num_heads, qkv_bias=True, attn_drop=attn_drop, proj_drop=drop)
        self.drop_path = DropPath(drop_path) if drop_path>0. else nn.Identity()
        self.norm2 = nn.LayerNorm(dim)
        self.mlp = MLP(dim, int(dim*mlp_ratio), drop=drop)
    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm1(x)))
        x = x + self.drop_path(self.mlp(self.norm2(x)))
        return x

class ViT(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_chans=3, num_classes=10,
                 embed_dim=256, depth=6, num_heads=4, mlp_ratio=4.,
                 drop_rate=0., drop_path_rate=0.1):
        super().__init__()
        self.patch_embed = PatchEmbed(img_size, patch_size, in_chans, embed_dim)
        n_patches = self.patch_embed.n_patches
        self.cls_token = nn.Parameter(torch.zeros(1,1,embed_dim))
        self.pos_embed = nn.Parameter(torch.zeros(1, n_patches+1, embed_dim))
        self.pos_drop = nn.Dropout(p=drop_rate)
        # stochastic depth schedule
        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, depth)]
        self.blocks = nn.ModuleList([
            Block(embed_dim, num_heads, mlp_ratio, drop=drop_rate, attn_drop=drop_rate, drop_path=dpr[i])
            for i in range(depth)
        ])
        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Linear(embed_dim, num_classes)
        # init
        nn.init.trunc_normal_(self.pos_embed, std=0.02)
        nn.init.trunc_normal_(self.cls_token, std=0.02)

    def forward(self, x):
        B = x.shape[0]
        x = self.patch_embed(x)
        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.pos_drop(x)
        for blk in self.blocks:
            x = blk(x)
        x = self.norm(x)
        cls = x[:,0]
        out = self.head(cls)
        return out

# Instantiate model
model = ViT(img_size=32, patch_size=4, embed_dim=256, depth=6, num_heads=4,
            mlp_ratio=4.0, drop_rate=0.1, drop_path_rate=0.1).to(device)

# %%
# ==============================
# 5. Optimizer, Scheduler, EMA
# ==============================
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
opt = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.05)

epochs = 200
steps_per_epoch = len(train_loader)
total_steps = epochs * steps_per_epoch
warmup_steps = int(0.05 * total_steps)

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))
    progress = float(current_step - warmup_steps) / float(max(1, total_steps - warmup_steps))
    return 0.5 * (1.0 + math.cos(math.pi * progress))

scheduler = LambdaLR(opt, lr_lambda)

class ModelEMA:
    def __init__(self, model, decay=0.9999, device=None):
        self.ema = {k: v.detach().clone().to(device) for k,v in model.state_dict().items()}
        self.decay = decay; self.device = device
    def update(self, model):
        for k,v in model.state_dict().items():
            self.ema[k].mul_(self.decay).add_(v.detach().to(self.device), alpha=1.0-self.decay)
    def state_dict(self): return self.ema

ema = ModelEMA(model, decay=0.9999, device=device)

# %%
# ==============================
# 6. Training & Evaluation Loops
# ==============================
scaler = GradScaler()

def train_one_epoch(model, loader, opt, scheduler, epoch, device, ema=None, mixup_alpha=0.8):
    model.train()
    total_loss, total_correct, total = 0.0, 0, 0
    for x,y in loader:
        x,y = x.to(device), y.to(device)
        if mixup_alpha > 0:
            x, y_a, y_b, lam = mixup_data(x, y, mixup_alpha, device)
        opt.zero_grad()
        with autocast():
            logits = model(x)
            if mixup_alpha > 0:
                loss = mixup_criterion(criterion, logits, y_a, y_b, lam)
            else:
                loss = criterion(logits, y)
        scaler.scale(loss).backward()
        scaler.step(opt)
        scaler.update()
        scheduler.step()
        if ema is not None: ema.update(model)
        total_loss += loss.item() * x.size(0)
        preds = logits.argmax(dim=1)
        total_correct += (preds == y).sum().item()
        total += x.size(0)
    return total_loss/total, total_correct/total

@torch.no_grad()
def evaluate(model, loader, device):
    model.eval()
    total, correct = 0, 0
    for x,y in loader:
        x,y = x.to(device), y.to(device)
        logits = model(x)
        preds = logits.argmax(dim=1)
        total += x.size(0)
        correct += (preds == y).sum().item()
    return correct/total
# Out:
# /tmp/ipython-input-2975132809.py:4: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %%
# ==============================
# 7. Train Loop with checkpointing
# ==============================
best = 0.0
for epoch in range(1, epochs+1):
    tr_loss, tr_acc = train_one_epoch(model, train_loader, opt, scheduler, epoch, device, ema, mixup_alpha=0.8)
    val_acc = evaluate(model, val_loader, device)
    print(f"Epoch {epoch}/{epochs} - Train Loss {tr_loss:.4f} | Train Acc {tr_acc:.4f} | Val Acc {val_acc:.4f}")
    if val_acc > best:
        best = val_acc
        torch.save(model.state_dict(), "best_vit.pt")
        print(f"  ✅ Saved new best model @ epoch {epoch} with val_acc {val_acc:.4f}")
# Out:
# /tmp/ipython-input-2975132809.py:14: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/200 - Train Loss 2.2584 | Train Acc 0.1455 | Val Acc 0.2902
#   ✅ Saved new best model @ epoch 1 with val_acc 0.2902
# Epoch 2/200 - Train Loss 2.1540 | Train Acc 0.1779 | Val Acc 0.3111
#   ✅ Saved new best model @ epoch 2 with val_acc 0.3111
# Epoch 3/200 - Train Loss 2.0996 | Train Acc 0.2052 | Val Acc 0.3747
#   ✅ Saved new best model @ epoch 3 with val_acc 0.3747
# Epoch 4/200 - Train Loss 2.0582 | Train Acc 0.2057 | Val Acc 0.4200
#   ✅ Saved new best model @ epoch 4 with val_acc 0.4200
# Epoch 5/200 - Train Loss 2.0041 | Train Acc 0.2438 | Val Acc 0.4616
#   ✅ Saved new best model @ epoch 5 with val_acc 0.4616
# Epoch 6/200 - Train Loss 1.9567 | Train Acc 0.2629 | Val Acc 0.4889
#   ✅ Saved new best model @ epoch 6 with val_acc 0.4889
# Epoch 7/200 - Train Loss 1.9228 | Train Acc 0.2710 | Val Acc 0.5186
#   ✅ Saved new best model @ epoch 7 with val_acc 0.5186
# Epoch 8/200 - Train Loss 1.9004 | Train Acc 0.2778 | Val Acc 0.5527
#   ✅ Saved new best model @ epoch 8 with val_acc 0.5527
# Epoch 9/200 - Train Loss 1.8908 | Train Acc 0.2954 | Val Acc 0.5620
#   ✅ Saved new best model @ epoch 9 with val_acc 0.5620
# Epoch 10/200 - Train Loss 1.8808 | Train Acc 0.2849 | Val Acc 0.5549
# Epoch 11/200 - Train Loss 1.8525 | Train Acc 0.2827 | Val Acc 0.5385
# Epoch 12/200 - Train Loss 1.8543 | Train Acc 0.3044 | Val Acc 0.5961
#   ✅ Saved new best model @ epoch 12 with val_acc 0.5961
# Epoch 13/200 - Train Loss 1.8345 | Train Acc 0.3014 | Val Acc 0.5892
# Epoch 14/200 - Train Loss 1.8014 | Train Acc 0.3207 | Val Acc 0.6292
#   ✅ Saved new best model @ epoch 14 with val_acc 0.6292
# Epoch 15/200 - Train Loss 1.7784 | Train Acc 0.3036 | Val Acc 0.6166
# Epoch 16/200 - Train Loss 1.7694 | Train Acc 0.3326 | Val Acc 0.6448
#   ✅ Saved new best model @ epoch 16 with val_acc 0.6448
# Epoch 17/200 - Train Loss 1.7628 | Train Acc 0.3253 | Val Acc 0.6461
#   ✅ Saved new best model @ epoch 17 with val_acc 0.6461
# Epoch 18/200 - Train Loss 1.7610 | Train Acc 0.3344 | Val Acc 0.6264
# Epoch 19/200 - Train Loss 1.7395 | Train Acc 0.3479 | Val Acc 0.6709
#   ✅ Saved new best model @ epoch 19 with val_acc 0.6709
# Epoch 20/200 - Train Loss 1.7455 | Train Acc 0.3392 | Val Acc 0.6602
# Epoch 21/200 - Train Loss 1.7169 | Train Acc 0.3459 | Val Acc 0.6543
# Epoch 22/200 - Train Loss 1.7001 | Train Acc 0.3304 | Val Acc 0.6848
#   ✅ Saved new best model @ epoch 22 with val_acc 0.6848
# Epoch 23/200 - Train Loss 1.7244 | Train Acc 0.3446 | Val Acc 0.7046
#   ✅ Saved new best model @ epoch 23 with val_acc 0.7046
# Epoch 24/200 - Train Loss 1.6821 | Train Acc 0.3474 | Val Acc 0.6829
# Epoch 25/200 - Train Loss 1.6994 | Train Acc 0.3768 | Val Acc 0.7040
# Epoch 26/200 - Train Loss 1.6984 | Train Acc 0.3738 | Val Acc 0.7046
# Epoch 27/200 - Train Loss 1.6781 | Train Acc 0.3596 | Val Acc 0.7145
#   ✅ Saved new best model @ epoch 27 with val_acc 0.7145
# Epoch 28/200 - Train Loss 1.6720 | Train Acc 0.3442 | Val Acc 0.7212
#   ✅ Saved new best model @ epoch 28 with val_acc 0.7212
# Epoch 29/200 - Train Loss 1.6841 | Train Acc 0.3588 | Val Acc 0.7302
#   ✅ Saved new best model @ epoch 29 with val_acc 0.7302
# Epoch 30/200 - Train Loss 1.6702 | Train Acc 0.3670 | Val Acc 0.7224
# Epoch 31/200 - Train Loss 1.6609 | Train Acc 0.3625 | Val Acc 0.7363
#   ✅ Saved new best model @ epoch 31 with val_acc 0.7363
# Epoch 32/200 - Train Loss 1.6464 | Train Acc 0.3877 | Val Acc 0.7330
# Epoch 33/200 - Train Loss 1.6231 | Train Acc 0.3487 | Val Acc 0.7434
#   ✅ Saved new best model @ epoch 33 with val_acc 0.7434
# Epoch 34/200 - Train Loss 1.6337 | Train Acc 0.3686 | Val Acc 0.7475
#   ✅ Saved new best model @ epoch 34 with val_acc 0.7475
# Epoch 35/200 - Train Loss 1.6124 | Train Acc 0.3990 | Val Acc 0.7405
# Epoch 36/200 - Train Loss 1.6203 | Train Acc 0.3941 | Val Acc 0.7550
#   ✅ Saved new best model @ epoch 36 with val_acc 0.7550
# Epoch 37/200 - Train Loss 1.6253 | Train Acc 0.3944 | Val Acc 0.7528
# Epoch 38/200 - Train Loss 1.6082 | Train Acc 0.3727 | Val Acc 0.7492
# Epoch 39/200 - Train Loss 1.5980 | Train Acc 0.4003 | Val Acc 0.7611
#   ✅ Saved new best model @ epoch 39 with val_acc 0.7611
# Epoch 40/200 - Train Loss 1.6022 | Train Acc 0.4025 | Val Acc 0.7777
#   ✅ Saved new best model @ epoch 40 with val_acc 0.7777
# Epoch 41/200 - Train Loss 1.5998 | Train Acc 0.3840 | Val Acc 0.7778
#   ✅ Saved new best model @ epoch 41 with val_acc 0.7778
# Epoch 42/200 - Train Loss 1.6218 | Train Acc 0.3851 | Val Acc 0.7684
# Epoch 43/200 - Train Loss 1.6031 | Train Acc 0.3855 | Val Acc 0.7815
#   ✅ Saved new best model @ epoch 43 with val_acc 0.7815
# Epoch 44/200 - Train Loss 1.5751 | Train Acc 0.4011 | Val Acc 0.7620
# Epoch 45/200 - Train Loss 1.5987 | Train Acc 0.3943 | Val Acc 0.7833
#   ✅ Saved new best model @ epoch 45 with val_acc 0.7833
# Epoch 46/200 - Train Loss 1.5763 | Train Acc 0.3957 | Val Acc 0.7915
#   ✅ Saved new best model @ epoch 46 with val_acc 0.7915
# Epoch 47/200 - Train Loss 1.5674 | Train Acc 0.3826 | Val Acc 0.7820
# Epoch 48/200 - Train Loss 1.5806 | Train Acc 0.4013 | Val Acc 0.7943
#   ✅ Saved new best model @ epoch 48 with val_acc 0.7943
# Epoch 49/200 - Train Loss 1.5781 | Train Acc 0.3936 | Val Acc 0.7954
#   ✅ Saved new best model @ epoch 49 with val_acc 0.7954
# Epoch 50/200 - Train Loss 1.5922 | Train Acc 0.3874 | Val Acc 0.7928
# Epoch 51/200 - Train Loss 1.5508 | Train Acc 0.4059 | Val Acc 0.8004
#   ✅ Saved new best model @ epoch 51 with val_acc 0.8004
# Epoch 52/200 - Train Loss 1.5731 | Train Acc 0.3783 | Val Acc 0.7997
# Epoch 53/200 - Train Loss 1.5693 | Train Acc 0.4182 | Val Acc 0.8009
#   ✅ Saved new best model @ epoch 53 with val_acc 0.8009
# Epoch 54/200 - Train Loss 1.5695 | Train Acc 0.3919 | Val Acc 0.7935
# Epoch 55/200 - Train Loss 1.5542 | Train Acc 0.4039 | Val Acc 0.7995
# Epoch 56/200 - Train Loss 1.5362 | Train Acc 0.4071 | Val Acc 0.7989
# Epoch 57/200 - Train Loss 1.5521 | Train Acc 0.4497 | Val Acc 0.7963
# Epoch 58/200 - Train Loss 1.5514 | Train Acc 0.3958 | Val Acc 0.7965
# Epoch 59/200 - Train Loss 1.5341 | Train Acc 0.3928 | Val Acc 0.8059
#   ✅ Saved new best model @ epoch 59 with val_acc 0.8059
# Epoch 60/200 - Train Loss 1.5465 | Train Acc 0.4131 | Val Acc 0.7979
# Epoch 61/200 - Train Loss 1.5125 | Train Acc 0.3856 | Val Acc 0.8017
# Epoch 62/200 - Train Loss 1.5158 | Train Acc 0.4205 | Val Acc 0.8095
#   ✅ Saved new best model @ epoch 62 with val_acc 0.8095
# Epoch 63/200 - Train Loss 1.5069 | Train Acc 0.4198 | Val Acc 0.8173
#   ✅ Saved new best model @ epoch 63 with val_acc 0.8173
# Epoch 64/200 - Train Loss 1.5406 | Train Acc 0.4258 | Val Acc 0.8186
#   ✅ Saved new best model @ epoch 64 with val_acc 0.8186
# Epoch 65/200 - Train Loss 1.5029 | Train Acc 0.4269 | Val Acc 0.8132
# Epoch 66/200 - Train Loss 1.5197 | Train Acc 0.4317 | Val Acc 0.8256
#   ✅ Saved new best model @ epoch 66 with val_acc 0.8256
# Epoch 67/200 - Train Loss 1.5247 | Train Acc 0.4200 | Val Acc 0.8230
# Epoch 68/200 - Train Loss 1.5054 | Train Acc 0.4050 | Val Acc 0.8165
# Epoch 69/200 - Train Loss 1.5193 | Train Acc 0.4318 | Val Acc 0.8106
# Epoch 70/200 - Train Loss 1.5153 | Train Acc 0.4383 | Val Acc 0.8189
# Epoch 71/200 - Train Loss 1.5187 | Train Acc 0.4302 | Val Acc 0.8260
#   ✅ Saved new best model @ epoch 71 with val_acc 0.8260
# Epoch 72/200 - Train Loss 1.4989 | Train Acc 0.4118 | Val Acc 0.8280
#   ✅ Saved new best model @ epoch 72 with val_acc 0.8280
# Epoch 73/200 - Train Loss 1.4994 | Train Acc 0.4375 | Val Acc 0.8315
#   ✅ Saved new best model @ epoch 73 with val_acc 0.8315
# Epoch 74/200 - Train Loss 1.4666 | Train Acc 0.4238 | Val Acc 0.8262
# Epoch 75/200 - Train Loss 1.4985 | Train Acc 0.4555 | Val Acc 0.8288
# Epoch 76/200 - Train Loss 1.5018 | Train Acc 0.4237 | Val Acc 0.8334
#   ✅ Saved new best model @ epoch 76 with val_acc 0.8334
# Epoch 77/200 - Train Loss 1.4806 | Train Acc 0.4227 | Val Acc 0.8375
#   ✅ Saved new best model @ epoch 77 with val_acc 0.8375
# Epoch 78/200 - Train Loss 1.4792 | Train Acc 0.4308 | Val Acc 0.8265
# Epoch 79/200 - Train Loss 1.4528 | Train Acc 0.4144 | Val Acc 0.8312
# Epoch 80/200 - Train Loss 1.4601 | Train Acc 0.4491 | Val Acc 0.8389
#   ✅ Saved new best model @ epoch 80 with val_acc 0.8389
# Epoch 81/200 - Train Loss 1.5041 | Train Acc 0.4273 | Val Acc 0.8422
#   ✅ Saved new best model @ epoch 81 with val_acc 0.8422
# Epoch 82/200 - Train Loss 1.4641 | Train Acc 0.4281 | Val Acc 0.8386
# Epoch 83/200 - Train Loss 1.4852 | Train Acc 0.4489 | Val Acc 0.8409
# Epoch 84/200 - Train Loss 1.4848 | Train Acc 0.4442 | Val Acc 0.8408
# Epoch 85/200 - Train Loss 1.4472 | Train Acc 0.4209 | Val Acc 0.8403
# Epoch 86/200 - Train Loss 1.4632 | Train Acc 0.4429 | Val Acc 0.8344
# Epoch 87/200 - Train Loss 1.4859 | Train Acc 0.4578 | Val Acc 0.8444
#   ✅ Saved new best model @ epoch 87 with val_acc 0.8444
# Epoch 88/200 - Train Loss 1.4652 | Train Acc 0.4363 | Val Acc 0.8370
# Epoch 89/200 - Train Loss 1.4350 | Train Acc 0.4076 | Val Acc 0.8384
# Epoch 90/200 - Train Loss 1.4748 | Train Acc 0.4397 | Val Acc 0.8509
#   ✅ Saved new best model @ epoch 90 with val_acc 0.8509
# Epoch 91/200 - Train Loss 1.4429 | Train Acc 0.4260 | Val Acc 0.8501
# Epoch 92/200 - Train Loss 1.4642 | Train Acc 0.4474 | Val Acc 0.8482
# Epoch 93/200 - Train Loss 1.4767 | Train Acc 0.4483 | Val Acc 0.8481
# Epoch 94/200 - Train Loss 1.4479 | Train Acc 0.4365 | Val Acc 0.8488
# Epoch 95/200 - Train Loss 1.4440 | Train Acc 0.4381 | Val Acc 0.8518
#   ✅ Saved new best model @ epoch 95 with val_acc 0.8518
# Epoch 96/200 - Train Loss 1.4543 | Train Acc 0.4558 | Val Acc 0.8422
# Epoch 97/200 - Train Loss 1.4030 | Train Acc 0.4286 | Val Acc 0.8438
# Epoch 98/200 - Train Loss 1.4488 | Train Acc 0.4497 | Val Acc 0.8551
#   ✅ Saved new best model @ epoch 98 with val_acc 0.8551
# Epoch 99/200 - Train Loss 1.4283 | Train Acc 0.4324 | Val Acc 0.8564
#   ✅ Saved new best model @ epoch 99 with val_acc 0.8564
# Epoch 100/200 - Train Loss 1.4453 | Train Acc 0.4500 | Val Acc 0.8523
# Epoch 101/200 - Train Loss 1.4445 | Train Acc 0.4414 | Val Acc 0.8540
# Epoch 102/200 - Train Loss 1.4342 | Train Acc 0.4464 | Val Acc 0.8564
# Epoch 103/200 - Train Loss 1.4248 | Train Acc 0.4714 | Val Acc 0.8494
# Epoch 104/200 - Train Loss 1.4236 | Train Acc 0.4696 | Val Acc 0.8617
#   ✅ Saved new best model @ epoch 104 with val_acc 0.8617
# Epoch 105/200 - Train Loss 1.4557 | Train Acc 0.4368 | Val Acc 0.8601
# Epoch 106/200 - Train Loss 1.4204 | Train Acc 0.4590 | Val Acc 0.8629
#   ✅ Saved new best model @ epoch 106 with val_acc 0.8629
# Epoch 107/200 - Train Loss 1.4521 | Train Acc 0.4274 | Val Acc 0.8599
# Epoch 108/200 - Train Loss 1.4556 | Train Acc 0.4108 | Val Acc 0.8613
# Epoch 109/200 - Train Loss 1.4360 | Train Acc 0.4375 | Val Acc 0.8625
# Epoch 110/200 - Train Loss 1.4540 | Train Acc 0.4383 | Val Acc 0.8632
#   ✅ Saved new best model @ epoch 110 with val_acc 0.8632
# Epoch 111/200 - Train Loss 1.4257 | Train Acc 0.4416 | Val Acc 0.8637
#   ✅ Saved new best model @ epoch 111 with val_acc 0.8637
# Epoch 112/200 - Train Loss 1.4068 | Train Acc 0.4508 | Val Acc 0.8658
#   ✅ Saved new best model @ epoch 112 with val_acc 0.8658
# Epoch 113/200 - Train Loss 1.3904 | Train Acc 0.4507 | Val Acc 0.8606
# Epoch 114/200 - Train Loss 1.4000 | Train Acc 0.4498 | Val Acc 0.8631
# Epoch 115/200 - Train Loss 1.3922 | Train Acc 0.4681 | Val Acc 0.8624
# Epoch 116/200 - Train Loss 1.4235 | Train Acc 0.4136 | Val Acc 0.8618
# Epoch 117/200 - Train Loss 1.4104 | Train Acc 0.4458 | Val Acc 0.8672
#   ✅ Saved new best model @ epoch 117 with val_acc 0.8672
# Epoch 118/200 - Train Loss 1.4269 | Train Acc 0.4703 | Val Acc 0.8600
# Epoch 119/200 - Train Loss 1.4131 | Train Acc 0.4780 | Val Acc 0.8661
# Epoch 120/200 - Train Loss 1.4477 | Train Acc 0.4446 | Val Acc 0.8712
#   ✅ Saved new best model @ epoch 120 with val_acc 0.8712
# Epoch 121/200 - Train Loss 1.4231 | Train Acc 0.4380 | Val Acc 0.8694
# Epoch 122/200 - Train Loss 1.3949 | Train Acc 0.4453 | Val Acc 0.8665
# Epoch 123/200 - Train Loss 1.3730 | Train Acc 0.4657 | Val Acc 0.8674
# Epoch 124/200 - Train Loss 1.3770 | Train Acc 0.4623 | Val Acc 0.8740
#   ✅ Saved new best model @ epoch 124 with val_acc 0.8740
# Epoch 125/200 - Train Loss 1.3989 | Train Acc 0.4502 | Val Acc 0.8686
# Epoch 126/200 - Train Loss 1.4051 | Train Acc 0.4274 | Val Acc 0.8722
# Epoch 127/200 - Train Loss 1.4129 | Train Acc 0.4478 | Val Acc 0.8756
#   ✅ Saved new best model @ epoch 127 with val_acc 0.8756
# Epoch 128/200 - Train Loss 1.3857 | Train Acc 0.4671 | Val Acc 0.8709
# Epoch 129/200 - Train Loss 1.3962 | Train Acc 0.4579 | Val Acc 0.8721
# Epoch 130/200 - Train Loss 1.3723 | Train Acc 0.4685 | Val Acc 0.8730
# Epoch 131/200 - Train Loss 1.3351 | Train Acc 0.4572 | Val Acc 0.8730
# Epoch 132/200 - Train Loss 1.3872 | Train Acc 0.4305 | Val Acc 0.8732
# Epoch 133/200 - Train Loss 1.3660 | Train Acc 0.4558 | Val Acc 0.8776
#   ✅ Saved new best model @ epoch 133 with val_acc 0.8776
# Epoch 134/200 - Train Loss 1.4205 | Train Acc 0.4514 | Val Acc 0.8769
# Epoch 135/200 - Train Loss 1.3988 | Train Acc 0.4569 | Val Acc 0.8744
# Epoch 136/200 - Train Loss 1.3978 | Train Acc 0.4584 | Val Acc 0.8764
# Epoch 137/200 - Train Loss 1.3815 | Train Acc 0.4731 | Val Acc 0.8789
#   ✅ Saved new best model @ epoch 137 with val_acc 0.8789
# Epoch 138/200 - Train Loss 1.3927 | Train Acc 0.4516 | Val Acc 0.8740
# Epoch 139/200 - Train Loss 1.3750 | Train Acc 0.4562 | Val Acc 0.8793
#   ✅ Saved new best model @ epoch 139 with val_acc 0.8793
# Epoch 140/200 - Train Loss 1.3332 | Train Acc 0.4545 | Val Acc 0.8760
# Epoch 141/200 - Train Loss 1.3719 | Train Acc 0.4693 | Val Acc 0.8777
# Epoch 142/200 - Train Loss 1.3498 | Train Acc 0.4798 | Val Acc 0.8819
#   ✅ Saved new best model @ epoch 142 with val_acc 0.8819
# Epoch 143/200 - Train Loss 1.3758 | Train Acc 0.4544 | Val Acc 0.8759
# Epoch 144/200 - Train Loss 1.3951 | Train Acc 0.4422 | Val Acc 0.8787
# Epoch 145/200 - Train Loss 1.3828 | Train Acc 0.4553 | Val Acc 0.8782
# Epoch 146/200 - Train Loss 1.3356 | Train Acc 0.4586 | Val Acc 0.8812
# Epoch 147/200 - Train Loss 1.3833 | Train Acc 0.4639 | Val Acc 0.8836
#   ✅ Saved new best model @ epoch 147 with val_acc 0.8836
# Epoch 148/200 - Train Loss 1.3809 | Train Acc 0.4478 | Val Acc 0.8810
# Epoch 149/200 - Train Loss 1.3955 | Train Acc 0.4349 | Val Acc 0.8864
#   ✅ Saved new best model @ epoch 149 with val_acc 0.8864
# Epoch 150/200 - Train Loss 1.3230 | Train Acc 0.4664 | Val Acc 0.8850
# Epoch 151/200 - Train Loss 1.3676 | Train Acc 0.4645 | Val Acc 0.8774
# Epoch 152/200 - Train Loss 1.3594 | Train Acc 0.4536 | Val Acc 0.8856
# Epoch 153/200 - Train Loss 1.3584 | Train Acc 0.4639 | Val Acc 0.8790
# Epoch 154/200 - Train Loss 1.3825 | Train Acc 0.4524 | Val Acc 0.8839
# Epoch 155/200 - Train Loss 1.3635 | Train Acc 0.4678 | Val Acc 0.8808
# Epoch 156/200 - Train Loss 1.3801 | Train Acc 0.4590 | Val Acc 0.8811
# Epoch 157/200 - Train Loss 1.3555 | Train Acc 0.4693 | Val Acc 0.8807
# Epoch 158/200 - Train Loss 1.3639 | Train Acc 0.4591 | Val Acc 0.8839
# Epoch 159/200 - Train Loss 1.3616 | Train Acc 0.4470 | Val Acc 0.8862
# Epoch 160/200 - Train Loss 1.3623 | Train Acc 0.4479 | Val Acc 0.8872
#   ✅ Saved new best model @ epoch 160 with val_acc 0.8872
# Epoch 161/200 - Train Loss 1.3660 | Train Acc 0.4896 | Val Acc 0.8836
# Epoch 162/200 - Train Loss 1.3391 | Train Acc 0.4718 | Val Acc 0.8837
# Epoch 163/200 - Train Loss 1.3383 | Train Acc 0.4964 | Val Acc 0.8879
#   ✅ Saved new best model @ epoch 163 with val_acc 0.8879
# Epoch 164/200 - Train Loss 1.3524 | Train Acc 0.4632 | Val Acc 0.8860
# Epoch 165/200 - Train Loss 1.3192 | Train Acc 0.4905 | Val Acc 0.8892
#   ✅ Saved new best model @ epoch 165 with val_acc 0.8892
# Epoch 166/200 - Train Loss 1.3348 | Train Acc 0.4648 | Val Acc 0.8882
# Epoch 167/200 - Train Loss 1.3505 | Train Acc 0.4659 | Val Acc 0.8886
# Epoch 168/200 - Train Loss 1.3437 | Train Acc 0.4664 | Val Acc 0.8890
# Epoch 169/200 - Train Loss 1.3601 | Train Acc 0.4617 | Val Acc 0.8901
#   ✅ Saved new best model @ epoch 169 with val_acc 0.8901
# Epoch 170/200 - Train Loss 1.3474 | Train Acc 0.4499 | Val Acc 0.8862
# Epoch 171/200 - Train Loss 1.3560 | Train Acc 0.4473 | Val Acc 0.8869
# Epoch 172/200 - Train Loss 1.3495 | Train Acc 0.4596 | Val Acc 0.8914
#   ✅ Saved new best model @ epoch 172 with val_acc 0.8914
# Epoch 173/200 - Train Loss 1.3521 | Train Acc 0.4820 | Val Acc 0.8905
# Epoch 174/200 - Train Loss 1.3271 | Train Acc 0.4935 | Val Acc 0.8924
#   ✅ Saved new best model @ epoch 174 with val_acc 0.8924
# Epoch 175/200 - Train Loss 1.3471 | Train Acc 0.4678 | Val Acc 0.8899
# Epoch 176/200 - Train Loss 1.3083 | Train Acc 0.4568 | Val Acc 0.8909
# Epoch 177/200 - Train Loss 1.3290 | Train Acc 0.5063 | Val Acc 0.8899
# Epoch 178/200 - Train Loss 1.3440 | Train Acc 0.5065 | Val Acc 0.8889
# Epoch 179/200 - Train Loss 1.3427 | Train Acc 0.4645 | Val Acc 0.8906
# Epoch 180/200 - Train Loss 1.3540 | Train Acc 0.4606 | Val Acc 0.8923
# Epoch 181/200 - Train Loss 1.3455 | Train Acc 0.4851 | Val Acc 0.8903
# Epoch 182/200 - Train Loss 1.3116 | Train Acc 0.4972 | Val Acc 0.8920
# Epoch 183/200 - Train Loss 1.3430 | Train Acc 0.4662 | Val Acc 0.8899
# Epoch 184/200 - Train Loss 1.3368 | Train Acc 0.4779 | Val Acc 0.8910
# Epoch 185/200 - Train Loss 1.3347 | Train Acc 0.4704 | Val Acc 0.8919
# Epoch 186/200 - Train Loss 1.3675 | Train Acc 0.4884 | Val Acc 0.8918
# Epoch 187/200 - Train Loss 1.3116 | Train Acc 0.5136 | Val Acc 0.8905
# Epoch 188/200 - Train Loss 1.3315 | Train Acc 0.4722 | Val Acc 0.8921
# Epoch 189/200 - Train Loss 1.3315 | Train Acc 0.4791 | Val Acc 0.8908
# Epoch 190/200 - Train Loss 1.3442 | Train Acc 0.4596 | Val Acc 0.8911
# Epoch 191/200 - Train Loss 1.3345 | Train Acc 0.4579 | Val Acc 0.8910
# Epoch 192/200 - Train Loss 1.3562 | Train Acc 0.4754 | Val Acc 0.8916
# Epoch 193/200 - Train Loss 1.3410 | Train Acc 0.4790 | Val Acc 0.8924
# Epoch 194/200 - Train Loss 1.3600 | Train Acc 0.4826 | Val Acc 0.8916
# Epoch 195/200 - Train Loss 1.3579 | Train Acc 0.4800 | Val Acc 0.8919
# Epoch 196/200 - Train Loss 1.3345 | Train Acc 0.4822 | Val Acc 0.8912
# Epoch 197/200 - Train Loss 1.2964 | Train Acc 0.4924 | Val Acc 0.8915
# Epoch 198/200 - Train Loss 1.3311 | Train Acc 0.4967 | Val Acc 0.8916
# Epoch 199/200 - Train Loss 1.3165 | Train Acc 0.4593 | Val Acc 0.8916
# Epoch 200/200 - Train Loss 1.3292 | Train Acc 0.4782 | Val Acc 0.8916
